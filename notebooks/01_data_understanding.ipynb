# %%
import pandas as pd

# %%
df_raw = pd.read_csv("../data/raws/train(2).csv")

# %%
df_raw.head(10)
# Out:
#         dur  proto service state  spkts  dpkts  sbytes  dbytes           rate  \
# 0  0.022895    tcp       -   FIN     40     42    2542   23508    3537.890234
# 1  0.004540    udp       -   CON      4      4     568     304    1541.850183
# 2  0.761113    tcp    http   FIN     10     20     812   15532      38.102096
# 3  0.000003  emcon       -   INT      2      0     180       0  333333.321500
# 4  0.000008    udp     dns   INT      2      0     114       0  125000.000300
# 5  0.000008    udp     dns   INT      2      0     114       0  125000.000300
# 6  0.000009    udp       -   INT      2      0     104       0  111111.107200
# 7  0.697741    tcp    http   FIN     10      8     836    1326      24.364342
# 8  1.347953    tcp    http   FIN     28    134    1894  169716     119.440370
# 9  1.851700    tcp       -   FIN     10      8     946     354       9.180753
#
#    sttl  ...  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  \
# ...

# %%
df_raw.shape
# Out:
# (180371, 43)

# %%
df_raw.columns
# Out:
# Index(['dur', 'proto', 'service', 'state', 'spkts', 'dpkts', 'sbytes',
#        'dbytes', 'rate', 'sttl', 'dttl', 'sload', 'dload', 'sloss', 'dloss',
#        'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin',
#        'tcprtt', 'synack', 'ackdat', 'smean', 'dmean', 'trans_depth',
#        'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm',
#        'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm',
#        'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm',
#        'ct_srv_dst', 'is_sm_ips_ports', 'Label'],
#       dtype='str')

# %%
df_raw.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 180371 entries, 0 to 180370
# Data columns (total 43 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   dur                180371 non-null  float64
#  1   proto              180371 non-null  str
#  2   service            180371 non-null  str
#  3   state              180371 non-null  str
#  4   spkts              180371 non-null  int64
#  5   dpkts              180371 non-null  int64
#  6   sbytes             180371 non-null  int64
#  7   dbytes             180371 non-null  int64
#  8   rate               180371 non-null  float64
#  9   sttl               180371 non-null  int64
#  10  dttl               180371 non-null  int64
#  11  sload              180371 non-null  float64
#  12  dload              180371 non-null  float64
#  13  sloss              180371 non-null  int64
#  14  dloss              180371 non-null  int64
#  15  sinpkt             180371 non-null  float64
# ...

# %%
df_raw.describe()
# Out:
#                  dur          spkts          dpkts        sbytes  \
# count  180371.000000  180371.000000  180371.000000  1.803710e+05
# mean        1.259370      19.760848      18.688065  8.512775e+03
# std         6.031214     137.415753     117.460464  1.755446e+05
# min         0.000000       1.000000       0.000000  2.400000e+01
# 25%         0.000008       2.000000       0.000000  1.140000e+02
# 50%         0.004342       4.000000       2.000000  5.280000e+02
# 75%         0.687237      12.000000      10.000000  1.356000e+03
# max        59.999989   10646.000000   11018.000000  1.435577e+07
#
#              dbytes          rate           sttl           dttl         sload  \
# count  1.803710e+05  1.803710e+05  180371.000000  180371.000000  1.803710e+05
# mean   1.463912e+04  9.108393e+04     179.965848      85.045412  7.053927e+07
# std    1.537443e+05  1.599175e+05     102.476930     112.877973  1.851258e+08
# ...

# %%
df_raw.isna().sum().sort_values(ascending=False)
# Out:
# dur                  0
# proto                0
# service              0
# state                0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ct_src_ltm           0
# ...

# %%
df_raw = df_raw.dropna()

# %%
df_raw.isna().sum().sort_values(ascending=False)
# Out:
# dur                  0
# proto                0
# service              0
# state                0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# dinpkt               0
# sjit                 0
# djit                 0
# swin                 0
# stcpb                0
# dtcpb                0
# dwin                 0
# tcprtt               0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ct_src_ltm           0
# ...

# %%
df_raw.duplicated().sum()
# Out:
# np.int64(61522)

# %%
df_raw = df_raw.drop_duplicates()

# %%
df_raw.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_raw["Label"].value_counts()
# Out:
# Label
# 0    60874
# 2    20302
# 3    15108
# 5     7220
# 1     6888
# 4     4380
# 6     1525
# 7     1406
# 8     1025
# 9      121
# Name: count, dtype: int64

# %%
df_raw["proto"].value_counts()
# Out:
# proto
# tcp           83085
# udp           26500
# unas           2909
# ospf            804
# arp             661
#               ...
# scps             30
# nsfnet-igp       28
# tlsp             26
# igmp             23
# icmp              8
# Name: count, Length: 132, dtype: int64

# %%
df_raw["proto"].nunique()
# Out:
# 132

# %%
df_raw["proto"].unique()
# Out:
# <StringArray>
# [        'tcp',         'udp',       'emcon',     'pri-enc',        'unas',
#          'prm',   'aes-sp3-d',     'trunk-1',         'cbt',         'pup',
#  ...
#          'snp',     'bbn-rcc',      'netblt',        'isis',         'dcn',
#          'ddp',        'icmp', 'compaq-peer',        'sdrp',        'vrrp']
# Length: 132, dtype: str

# %%
df_raw["service"].nunique()
# Out:
# 13

# %%
df_raw["service"].unique()
# Out:
# <StringArray>
# [       '-',     'http',      'dns',      'ftp',      'ssh',     'smtp',
#  'ftp-data',     'pop3',     'dhcp',     'snmp',      'ssl',      'irc',
#    'radius']
# Length: 13, dtype: str

# %%
df_raw["state"].nunique()
# Out:
# 9

# %%
df_raw["state"].unique()
# Out:
# <StringArray>
# ['FIN', 'CON', 'INT', 'REQ', 'RST', 'ECO', 'no', 'URN', 'ACC']
# Length: 9, dtype: str
